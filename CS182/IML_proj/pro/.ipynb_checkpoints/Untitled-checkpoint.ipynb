# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import GridSearchCV
from sklearn.metrics  import classification_report
from sklearn.svm import SVC
from sklearn.decomposition import PCA
import pandas as pd

# %%
lfw_people = fetch_lfw_people(min_faces_per_person=70,resize=0.4)
#第一个参数是每个人脸最少有几张照片，这里是只取那些大于70张照片的人。
#第二个参数改变照片的尺寸改为原来的0.4倍
lfw_people.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])

# %%
lfw_data = pd.DataFrame( lfw_people.data)	
lfw_data['species'] = lfw_people.target_names[lfw_people.target]	
lfw_data.head(3)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.996078  0.997386  0.990850  0.964706  0.758170  0.571242  0.700654
# 1  0.150327  0.196078  0.176471  0.190850  0.386928  0.473203  0.546405
# 2  0.339869  0.396078  0.491503  0.554248  0.598693  0.611765  0.606536
#
#           7         8         9  ...      1841      1842      1843      1844  \
# 0  0.794771  0.784314  0.769935  ...  0.426144  0.422222  0.414379  0.402614
# 1  0.615686  0.671895  0.694118  ...  0.240523  0.296732  0.307190  0.324183
# 2  0.627451  0.640523  0.652288  ...  0.428758  0.380392  0.410458  0.499346
#
#        1845      1846      1847      1848      1849        species
# 0  0.394771  0.390850  0.379085  0.388235  0.381699    Hugo Chavez
# 1  0.409150  0.488889  0.458824  0.443137  0.535948     Tony Blair
# 2  0.448366  0.482353  0.709804  0.722876  0.717647  George W Bush
#
# [3 rows x 1851 columns]

# %%
plt.imshow(lfw_people.images[5],cmap='gray')
plt.show()

# %%
n_samples,h,w=lfw_people.images.shape
print(n_samples)
print(h)
print(w)
# Out:
# 1288
# 50
# 37

# %%
lfw_people.data.shape
# Out:
# (1288, 1850)

# %%
lfw_people.target#target就是标签也就是一些数字
# Out:
# array([5, 6, 3, ..., 5, 3, 5], dtype=int64)

# %%
target_names = lfw_people.target_names
target_names
# Out:
# array(['Ariel Sharon', 'Colin Powell', 'Donald Rumsfeld', 'George W Bush',
#        'Gerhard Schroeder', 'Hugo Chavez', 'Tony Blair'], dtype='<U17')

# %%
n_classes =lfw_people.target_names.shape[0]

# %%
x_train,x_test,y_train,y_test = train_test_split(lfw_people.data,lfw_people.target)
x_train.shape
# Out:
# (966, 1850)

# %%
model = SVC(kernel='rbf',class_weight='balanced')#如果不同类别各自的样本数量差距比较大，
#这时候构建的模型容易把所有的数据归类给样本量大的类别（这时候error rate反而会小）
#解决方法是取出等量的样本个数
#在分类的时候把样本多的权重小一点

model.fit(x_train,y_train)
# Out:
# SVC(class_weight='balanced')

# %%
predictions=model.predict(x_test)
print(classification_report(y_test,predictions,target_names=lfw_people.target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.61      0.79      0.69        14
#      Colin Powell       0.79      0.88      0.83        57
#   Donald Rumsfeld       0.90      0.70      0.79        37
#     George W Bush       0.89      0.88      0.89       132
# Gerhard Schroeder       0.58      0.62      0.60        29
#       Hugo Chavez       0.92      0.71      0.80        17
#        Tony Blair       0.71      0.75      0.73        36
#
#          accuracy                           0.81       322
#         macro avg       0.77      0.76      0.76       322
#      weighted avg       0.82      0.81      0.81       322

# %% [markdown]
# # PCA降维度

# %%
#现在数据的特征维度是1850可以考虑降低维度
n_components=100
pca=PCA(n_components=n_components,whiten=True).fit(lfw_people.data)
x_train_pca=pca.transform(x_train)
x_test_pca=pca.transform(x_test)

# %%
x_train_pca.shape
# Out:
# (966, 100)

# %%
model = SVC(kernel='rbf',class_weight='balanced')#如果不同类别各自的样本数量差距比较大，
#这时候构建的模型容易把所有的数据归类给样本量大的类别（这时候error rate反而会小）
#解决方法是取出等量的样本个数
#在分类的时候把样本多的权重小一点

model.fit(x_train_pca,y_train)
# Out:
# SVC(class_weight='balanced')

# %%
predictions=model.predict(x_test_pca)
print(classification_report(y_test,predictions,target_names=lfw_people.target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.93      0.93      0.93        14
#      Colin Powell       0.79      0.93      0.85        57
#   Donald Rumsfeld       1.00      0.73      0.84        37
#     George W Bush       0.87      0.96      0.91       132
# Gerhard Schroeder       0.79      0.66      0.72        29
#       Hugo Chavez       1.00      0.53      0.69        17
#        Tony Blair       0.83      0.81      0.82        36
#
#          accuracy                           0.86       322
#         macro avg       0.89      0.79      0.82       322
#      weighted avg       0.87      0.86      0.86       322

# %% [markdown]
# # 调参

# %%
param_grid={'C':[0.1,1,5,10,100],
           'gamma':[0.0005,0.001,0.005,0.01],}
#C是正则化参用于损失函数

#gamma 大（如 gamma=10）：核函数衰减快，模型更关注邻近样本，易过拟合（复杂边界）。
#gamma 小（如 gamma=0.01）：核函数衰减慢，决策边界平滑，易欠拟合。
"""SVM 的原始目标是找到一个最优超平面（决策边界）来最大化分类间隔。但现实中的数据往往是非线性可分的，这时就需要核函数：

线性 SVM：

直接用超平面 
wT x+b=0 分类，适用于线性可分数据。

优化目标是最小化∣∣w∣|^2（间隔最大化）。

非线性 SVM：

通过核函数将数据映射到高维空间，在高维空间中用超平面分类。

优化问题中，所有数据点仅以核函数 
"""
model=GridSearchCV(SVC(kernel='rbf',class_weight='balanced'),param_grid)
#传入param_grid之后会使用所有C和gamma参数的组合
model.fit(x_train_pca,y_train)
print(model.best_estimator_)
# Out:
# SVC(C=5, class_weight='balanced', gamma=0.005)

# %%
predictions=model.predict(x_test_pca)
print(classification_report(y_test,predictions,target_names=lfw_people.target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.88      1.00      0.93        14
#      Colin Powell       0.84      0.93      0.88        57
#   Donald Rumsfeld       0.96      0.73      0.83        37
#     George W Bush       0.89      0.96      0.93       132
# Gerhard Schroeder       0.75      0.62      0.68        29
#       Hugo Chavez       0.92      0.71      0.80        17
#        Tony Blair       0.75      0.75      0.75        36
#
#          accuracy                           0.86       322
#         macro avg       0.86      0.81      0.83       322
#      weighted avg       0.86      0.86      0.86       322

# %%
param_grid={'C':[3,4,5,6,7],
           'gamma':[0.003,0.004, 0.005, 0.006,0.007]}
model=GridSearchCV(SVC(kernel='rbf',class_weight='balanced'),param_grid)
#传入param_grid之后会使用所有C和gamma参数的组合
model.fit(x_train_pca,y_train)
print(model.best_estimator_)
# Out:
# SVC(C=3, class_weight='balanced', gamma=0.005)

# %%
predictions=model.predict(x_test_pca)
print(classification_report(y_test,predictions,target_names=lfw_people.target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.93      1.00      0.97        14
#      Colin Powell       0.83      0.93      0.88        57
#   Donald Rumsfeld       0.96      0.73      0.83        37
#     George W Bush       0.89      0.95      0.92       132
# Gerhard Schroeder       0.80      0.69      0.74        29
#       Hugo Chavez       0.92      0.71      0.80        17
#        Tony Blair       0.78      0.81      0.79        36
#
#          accuracy                           0.87       322
#         macro avg       0.88      0.83      0.85       322
#      weighted avg       0.87      0.87      0.87       322

# %% [markdown]
# # 画图

# %%
def plot_gallery(images, titles, h, w, n_rows=3, n_cols=5):
    plt.figure(figsize=(1.8 * n_cols, 2.4 * n_rows))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_rows * n_cols):
        plt.subplot(n_rows, n_cols, i + 1)  # 修正：n_rows 和 i+1（整数索引）
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title(titles[i], size=12)
        plt.xticks(())
        plt.yticks(())

def title(prediction, true_label, target_names):
    pred_name = target_names[prediction].split(' ')[-1]
    true_name = target_names[true_label].split(' ')[-1]
    return f'predicted: {pred_name}\ntrue:      {true_name}'

# 修正：传入 predictions[i] 和 y_test[i] 作为参数
prediction_titles = [title(predictions[i], y_test[i], target_names) for i in range(len(predictions))]
plot_gallery(x_test, prediction_titles, h, w)
plt.show()
